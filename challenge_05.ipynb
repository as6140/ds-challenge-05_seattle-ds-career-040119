# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('data.csv',header=None)
#rename columns
df.columns = ['4/1/19', '4/2/19', '4/3/19', '4/4/19', '4/5/19', '4/8/19']
df
# Out:
#      4/1/19    4/2/19   4/3/19   4/4/19   4/5/19   4/8/19
# 0   8:56 AM   9:00 AM  7:45 AM  7:45 AM  8:05 AM  7:45 AM
# 1   8:40 AM   8:40 AM  8:30 AM  8:30 AM  8:45 AM  8:20 AM
# 2   8:45 AM   8:20 AM  8:05 AM  8:00 AM  8:05 AM  8:00 AM
# 3   8:40 AM   8:40 AM  8:40 AM  8:25 AM  8:40 AM  8:40 AM
# 4   8:55 AM   8:50 AM  8:55 AM  8:10 AM  8:15 AM  8:05 AM
# 5   8:45 AM   8:45 AM  8:45 AM  8:40 AM  8:30 AM  8:40 AM
# 6   8:45 AM   8:54 AM  8:38 AM  8:40 AM  8:32 AM  8:41 AM
# 7    absent  11:00 AM  8:35 AM  8:15 AM  8:10 AM  8:10 AM
# 8   8:39 AM   8:13 AM  8:15 AM  8:12 AM  8:10 AM  8:00 AM
# 9   9:00 AM   8:50 AM  8:50 AM  8:50 AM  8:40 AM  8:45 AM
# 10  8:40 AM   8:50 AM  8:40 AM  8:34 AM  8:20 AM  8:30 AM
# 11  8:15 AM   8:30 AM  8:13 AM  8:30 AM  7:45 AM  8:40 AM
# 12  8:45 AM   8:55 AM  8:45 AM  8:45 AM  8:00 AM  8:45 AM
# 13  8:45 AM   8:45 AM  8:05 AM  8:00 AM  8:00 AM  8:00 AM
# 14  8:45 AM   8:45 AM  9:00 AM  9:00 AM  8:50 AM  9:00 AM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
# 4/1/19    23 non-null object
# 4/2/19    23 non-null object
# 4/3/19    23 non-null object
# 4/4/19    23 non-null object
# 4/5/19    23 non-null object
# 4/8/19    23 non-null object
# dtypes: object(6)
# memory usage: 1.2+ KB

# %%
df.loc[df['4/1/19'] == 'absent','4/1/19'] = '12:00 AM'

# %%
df
# Out:
#       4/1/19    4/2/19   4/3/19   4/4/19   4/5/19   4/8/19
# 0    8:56 AM   9:00 AM  7:45 AM  7:45 AM  8:05 AM  7:45 AM
# 1    8:40 AM   8:40 AM  8:30 AM  8:30 AM  8:45 AM  8:20 AM
# 2    8:45 AM   8:20 AM  8:05 AM  8:00 AM  8:05 AM  8:00 AM
# 3    8:40 AM   8:40 AM  8:40 AM  8:25 AM  8:40 AM  8:40 AM
# 4    8:55 AM   8:50 AM  8:55 AM  8:10 AM  8:15 AM  8:05 AM
# 5    8:45 AM   8:45 AM  8:45 AM  8:40 AM  8:30 AM  8:40 AM
# 6    8:45 AM   8:54 AM  8:38 AM  8:40 AM  8:32 AM  8:41 AM
# 7   12:00 AM  11:00 AM  8:35 AM  8:15 AM  8:10 AM  8:10 AM
# 8    8:39 AM   8:13 AM  8:15 AM  8:12 AM  8:10 AM  8:00 AM
# 9    9:00 AM   8:50 AM  8:50 AM  8:50 AM  8:40 AM  8:45 AM
# 10   8:40 AM   8:50 AM  8:40 AM  8:34 AM  8:20 AM  8:30 AM
# 11   8:15 AM   8:30 AM  8:13 AM  8:30 AM  7:45 AM  8:40 AM
# 12   8:45 AM   8:55 AM  8:45 AM  8:45 AM  8:00 AM  8:45 AM
# 13   8:45 AM   8:45 AM  8:05 AM  8:00 AM  8:00 AM  8:00 AM
# 14   8:45 AM   8:45 AM  9:00 AM  9:00 AM  8:50 AM  9:00 AM
# ...

# %%
df = df.applymap(lambda x: pd.Timestamp.strptime(x,"%I:%M %p"))
df
# Out:
#                 4/1/19              4/2/19              4/3/19  \
# 0  1900-01-01 08:56:00 1900-01-01 09:00:00 1900-01-01 07:45:00
# 1  1900-01-01 08:40:00 1900-01-01 08:40:00 1900-01-01 08:30:00
# 2  1900-01-01 08:45:00 1900-01-01 08:20:00 1900-01-01 08:05:00
# 3  1900-01-01 08:40:00 1900-01-01 08:40:00 1900-01-01 08:40:00
# 4  1900-01-01 08:55:00 1900-01-01 08:50:00 1900-01-01 08:55:00
# 5  1900-01-01 08:45:00 1900-01-01 08:45:00 1900-01-01 08:45:00
# 6  1900-01-01 08:45:00 1900-01-01 08:54:00 1900-01-01 08:38:00
# 7  1900-01-01 00:00:00 1900-01-01 11:00:00 1900-01-01 08:35:00
# 8  1900-01-01 08:39:00 1900-01-01 08:13:00 1900-01-01 08:15:00
# 9  1900-01-01 09:00:00 1900-01-01 08:50:00 1900-01-01 08:50:00
# 10 1900-01-01 08:40:00 1900-01-01 08:50:00 1900-01-01 08:40:00
# 11 1900-01-01 08:15:00 1900-01-01 08:30:00 1900-01-01 08:13:00
# 12 1900-01-01 08:45:00 1900-01-01 08:55:00 1900-01-01 08:45:00
# 13 1900-01-01 08:45:00 1900-01-01 08:45:00 1900-01-01 08:05:00
# ...

# %%
x1 = sorted(df['4/1/19'].unique())
x2 = sorted(df['4/2/19'].unique())
x3 = sorted(df['4/3/19'].unique())
x4 = sorted(df['4/4/19'].unique())
x5 = sorted(df['4/5/19'].unique())
x8 = sorted(df['4/8/19'].unique())

y1 = df['4/1/19'].value_counts()
y2 = df['4/2/19'].value_counts()
y3 = df['4/3/19'].value_counts()
y4 = df['4/4/19'].value_counts()
y5 = df['4/5/19'].value_counts()
y8 = df['4/8/19'].value_counts()

# %%
x1
# Out:
# [numpy.datetime64('1900-01-01T00:00:00.000000000'),
#  numpy.datetime64('1900-01-01T08:15:00.000000000'),
#  numpy.datetime64('1900-01-01T08:39:00.000000000'),
#  numpy.datetime64('1900-01-01T08:40:00.000000000'),
#  numpy.datetime64('1900-01-01T08:45:00.000000000'),
#  numpy.datetime64('1900-01-01T08:50:00.000000000'),
#  numpy.datetime64('1900-01-01T08:55:00.000000000'),
#  numpy.datetime64('1900-01-01T08:56:00.000000000'),
#  numpy.datetime64('1900-01-01T09:00:00.000000000')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
# 4/1/19    23 non-null datetime64[ns]
# 4/2/19    23 non-null datetime64[ns]
# 4/3/19    23 non-null datetime64[ns]
# 4/4/19    23 non-null datetime64[ns]
# 4/5/19    23 non-null datetime64[ns]
# 4/8/19    23 non-null datetime64[ns]
# dtypes: datetime64[ns](6)
# memory usage: 1.2 KB

# %%
fig, ax = plt.subplots(figsize = (10,10), tight_layout=True)

ax.hist(x1,bins=8)

ax.set_title('')
ax.set_xlabel('')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ## TRYING IT DIFFERENTLY

# %%
raw_data = pd.read_csv('data.csv',header=None)

# %%
data = raw_data.values.reshape(-1)
data.shape
# Out:
# (138,)

# %%
def convert_time_to_minutes(time_text: str) -> int:
    '''Converts time formatted as 'H:MM AM' '''
    try:
        time_delta = pd.Timestamp(time_text) - pd.Timestamp("9:00 am")
        return int(time_delta.total_seconds() / 60)
    except ValueError:
        return None

# %%
minutes_early_or_late = [convert_time_to_minutes(time_text) for time_text in data]

# %%
y = [value for value in minutes_early_or_late if value is not None]

# %%
fig, ax = plt.subplots()
ax.hist(y, bins=20)
plt.show()
